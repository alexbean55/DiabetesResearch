# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
from functions.load_data import *
from functions.clean_data import *

# %%
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
df = load_diabetes_data()
df_clean = clean_feature_data(df)
display(df_clean.head())
print(df_clean.shape)
# Out:
#   house_family_person_id diabetes  age smoker     sex coronary_heart_disease  \
# 0                  1_2_1       NO   24     NO  FEMALE                     NO
# 1                  2_1_1       NO   76     NO    MALE                     NO
# 2                  3_1_2       NO   36     NO  FEMALE                     NO
# 3                  5_1_1       NO   35    YES  FEMALE                     NO
# 4                 10_1_5       NO   20     NO  FEMALE                     NO
#
#    weight had_high_cholesterol   class_of_worker  years_on_job  ...  \
# 0   125.0                   NO   PRIVATE COMPANY           2.0  ...
# 1   190.0                   NO  STATE GOVERNMENT          25.0  ...
# 2   225.0                   NO   PRIVATE COMPANY           2.0  ...
# 3   240.0                   NO   PRIVATE COMPANY           1.0  ...
# 4   103.0                   NO           MISSING           0.0  ...
#
#    more_than_one_job kidney_condition liver_condition cant_afford_meds  \
# 0                 NO               NO              NO               NO
# 1            MISSING               NO              NO               NO
# 2                 NO               NO              NO              YES
# 3                 NO               NO              NO              YES
# 4            MISSING               NO              NO               NO
#
#   skipped_meds       non_hispanic_race                     hispanic  \
# 0      MISSING  Black/African American  Not Hispanic/Spanish origin
# 1      MISSING                   White  Not Hispanic/Spanish origin
# 2           NO                   White             Mexican-American
# 3          YES                   White             Mexican-American
# 4      MISSING                   White                  Puerto Rico
#
#     primary_care    bmi                   age_group
# 0        MISSING  20.17         Young Adult (18-25)
# 1  Doctor office  27.26              Senior (76-85)
# 2        MISSING  38.62    Early Middle Age (36-45)
# 3        MISSING  39.93  Emerging Adulthood (26-35)
# 4  Doctor office  18.84         Young Adult (18-25)
#
# [5 rows x 26 columns]
# (32499, 26)

# %%
df17 = load_diabetes_data(path='../data/samadult17.csv')
df_clean17 = clean_feature_data(df17)
display(df_clean17.head())
print(df_clean17.shape)
# Out:
#   house_family_person_id diabetes  age smoker     sex coronary_heart_disease  \
# 0                  3_1_1       NO   65    YES  FEMALE                     NO
# 1                  9_1_1       NO   19     NO    MALE                     NO
# 2                 11_1_2       NO   45    YES    MALE                     NO
# 3                 15_1_1       NO   67    YES  FEMALE                     NO
# 4                 18_1_1       NO   40    YES    MALE                     NO
#
#    weight had_high_cholesterol  class_of_worker  years_on_job  ...  \
# 0   155.0                   NO  PRIVATE COMPANY          28.0  ...
# 1   180.0                   NO  PRIVATE COMPANY           0.0  ...
# 2   240.0                   NO  PRIVATE COMPANY          13.0  ...
# 3   236.0                   NO  PRIVATE COMPANY          13.0  ...
# 4   182.0                   NO  PRIVATE COMPANY          16.0  ...
#
#    more_than_one_job kidney_condition liver_condition cant_afford_meds  \
# 0            MISSING               NO              NO               NO
# 1            MISSING              YES             YES               NO
# 2                 NO               NO              NO              YES
# 3                 NO               NO              NO               NO
# 4                 NO               NO              NO               NO
#
#   skipped_meds non_hispanic_race                     hispanic   primary_care  \
# 0           NO             White  Not Hispanic/Spanish origin        MISSING
# 1           NO             White  Not Hispanic/Spanish origin        MISSING
# 2           NO             White  Not Hispanic/Spanish origin  Doctor office
# 3           NO             White  Not Hispanic/Spanish origin        MISSING
# 4      MISSING             White            Multiple Hispanic        MISSING
#
#      bmi                 age_group
# 0  29.28   Late Middle Age (56-65)
# 1  23.11       Young Adult (18-25)
# 2  35.44  Early Middle Age (36-45)
# 3  43.16      Early Senior (66-75)
# 4  32.24  Early Middle Age (36-45)
#
# [5 rows x 26 columns]
# (26311, 26)

# %% [markdown]
# # Analysis

# %% [markdown]
# ## 2016

# %%
diseases = ["diabetes",
            "smoker",
            "coronary_heart_disease",
            "had_high_cholesterol",
            "hypertension",
            "heart_condition",
            "cancer",
            "kidney_condition",
            "liver_condition",
            "cant_afford_meds",
            "skipped_meds",
           ]

# %%
dict_diseases_race = {}

for i in diseases:

    df_counts = df_clean.groupby(['non_hispanic_race', i]).agg({'house_family_person_id': 'count'}).reset_index()
    df_counts['Total'] = df_counts.groupby('non_hispanic_race')['house_family_person_id'].transform('sum')
    df_counts['Percentage'] = df_counts['house_family_person_id'] / df_counts['Total']
    
    df_counts = df_counts[~df_counts['non_hispanic_race'].isin(['Primary race not releasable', 'Multiple race, no primary race selected'])]
    df_counts_yes = df_counts[df_counts[i]=='YES'].sort_values('Percentage', ascending=False)

    races = df_counts_yes.head(3)['non_hispanic_race'].unique().tolist()

    dict_diseases_race[i] = races
    
    # print()

    # display(df_counts_yes)

# %%
df_diseases = pd.DataFrame(dict_diseases_race, index=['Most Affected', 'Second Most', 'Third Most']).T.sort_values(['Most Affected', 'Second Most', 'Third Most'])
df_diseases
# Out:
#                                            Most Affected  \
# hypertension                      Black/African American
# kidney_condition                  Black/African American
# cant_afford_meds                  Black/African American
# skipped_meds                      Black/African American
# had_high_cholesterol                            Filipino
# diabetes                Indian (American), Alaska Native
# smoker                  Indian (American), Alaska Native
# liver_condition                              Other Asian
# coronary_heart_disease                             White
# heart_condition                                    White
# cancer                                             White
#
#                                              Second Most  \
# hypertension                                    Filipino
# kidney_condition        Indian (American), Alaska Native
# cant_afford_meds        Indian (American), Alaska Native
# skipped_meds            Indian (American), Alaska Native
# had_high_cholesterol                               White
# diabetes                          Black/African American
# smoker                                             White
# liver_condition         Indian (American), Alaska Native
# coronary_heart_disease  Indian (American), Alaska Native
# heart_condition         Indian (American), Alaska Native
# cancer                                       Other Asian
#
#                                     Third Most
# hypertension                             White
# kidney_condition                         White
# cant_afford_meds                         White
# skipped_meds                             White
# had_high_cholesterol               Other Asian
# diabetes                              Filipino
# smoker                  Black/African American
# liver_condition                          White
# coronary_heart_disease  Black/African American
# heart_condition         Black/African American
# cancer                                Filipino

# %%
# df_diseases.reset_index().groupby(['Most Affected']).agg({'index':"unique"})

# %% [markdown]
# ## 2017

# %%
dict_diseases_race17 = {}

for i in diseases:

    df_counts = df_clean17.groupby(['non_hispanic_race', i]).agg({'house_family_person_id': 'count'}).reset_index()
    df_counts['Total'] = df_counts.groupby('non_hispanic_race')['house_family_person_id'].transform('sum')
    df_counts['Percentage'] = df_counts['house_family_person_id'] / df_counts['Total']
    
    df_counts = df_counts[~df_counts['non_hispanic_race'].isin(['Primary race not releasable', 'Multiple race, no primary race selected'])]
    df_counts_yes = df_counts[df_counts[i]=='YES'].sort_values('Percentage', ascending=False)

    races = df_counts_yes.head(3)['non_hispanic_race'].unique().tolist()

    dict_diseases_race17[i] = races

df_diseases17 = pd.DataFrame(dict_diseases_race17, index=['Most Affected', 'Second Most', 'Third Most']).T.sort_values(['Most Affected', 'Second Most', 'Third Most'])

# %%
df_diseases17
# Out:
#                                            Most Affected  \
# hypertension                      Black/African American
# skipped_meds                      Black/African American
# cant_afford_meds                  Black/African American
# coronary_heart_disease                          Filipino
# had_high_cholesterol                            Filipino
# diabetes                Indian (American), Alaska Native
# kidney_condition        Indian (American), Alaska Native
# liver_condition         Indian (American), Alaska Native
# smoker                  Indian (American), Alaska Native
# heart_condition                                    White
# cancer                                             White
#
#                                              Second Most  \
# hypertension            Indian (American), Alaska Native
# skipped_meds            Indian (American), Alaska Native
# cant_afford_meds        Indian (American), Alaska Native
# coronary_heart_disease                             White
# had_high_cholesterol                               White
# diabetes                          Black/African American
# kidney_condition                  Black/African American
# liver_condition                                 Filipino
# smoker                                             White
# heart_condition         Indian (American), Alaska Native
# cancer                                       Other Asian
#
#                                     Third Most
# hypertension                          Filipino
# skipped_meds                          Filipino
# cant_afford_meds                         White
# coronary_heart_disease  Black/African American
# had_high_cholesterol               Other Asian
# diabetes                              Filipino
# kidney_condition                         White
# liver_condition                    Other Asian
# smoker                  Black/African American
# heart_condition         Black/African American
# cancer                  Black/African American
