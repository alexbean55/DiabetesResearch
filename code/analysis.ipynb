# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
from functions.load_data import *
from functions.clean_data import *

# %%
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
df = load_diabetes_data()
display(df.head())
print(df.shape)
# Out:
#   house_family_person_id  diabetes  age  smoker  sex  coronary_heart_disease  \
# 0                  1_2_1         0   24       0    2                       0
# 1                  2_1_1         0   76       0    1                       0
# 2                  3_1_2         0   36       0    2                       0
# 3                  5_1_1         0   35       1    2                       0
# 4                 10_1_5         0   20       0    2                       0
#
#    weight  had_high_cholesterol class_of_worker years_on_job  ...  \
# 0     125                     0             1.0          2.0  ...
# 1     190                     0             3.0         25.0  ...
# 2     225                     0             1.0          2.0  ...
# 3     240                     0             1.0          1.0  ...
# 4     103                     0         MISSING      MISSING  ...
#
#    family_history_diabetes  ever_worked  more_than_one_job  kidney_condition  \
# 0                        0      MISSING                2.0                 0
# 1                        0          1.0            MISSING                 0
# 2                        1      MISSING                2.0                 0
# 3                        1      MISSING                2.0                 0
# 4                        1          2.0            MISSING                 0
#
#    liver_condition cant_afford_meds skipped_meds  non_hispanic_race  hispanic  \
# 0                0                2      MISSING                  2        12
# 1                0                2      MISSING                  1        12
# 2                0                1          2.0                  1         3
# 3                0                1          1.0                  1         3
# 4                0                2      MISSING                  1         1
#
#    primary_care
# 0       MISSING
# 1           2.0
# 2       MISSING
# 3       MISSING
# 4           2.0
#
# [5 rows x 24 columns]
# (32499, 24)

# %%
df_clean = clean_feature_data(df)

# %% [markdown]
# # Analysis

# %%
diseases = ["diabetes",
            "smoker",
            "coronary_heart_disease",
            "had_high_cholesterol",
            "hypertension",
            "heart_condition",
            "cancer",
            "kidney_condition",
            "liver_condition",
            "cant_afford_meds",
            "skipped_meds",
           ]

# %%
# for i in diseases:
#     print(df_clean[i].unique())

# %%
dict_diseases_race = {}

for i in diseases:

    df_counts = df_clean.groupby(['non_hispanic_race', i]).agg({'house_family_person_id': 'count'}).reset_index()
    df_counts['Total'] = df_counts.groupby('non_hispanic_race')['house_family_person_id'].transform('sum')
    df_counts['Percentage'] = df_counts['house_family_person_id'] / df_counts['Total']
    
    df_counts = df_counts[~df_counts['non_hispanic_race'].isin(['Primary race not releasable', 'Multiple race, no primary race selected'])]
    df_counts_yes = df_counts[df_counts[i]=='YES'].sort_values('Percentage', ascending=False)

    races = df_counts_yes.head(3)['non_hispanic_race'].unique().tolist()

    dict_diseases_race[i] = races
    
    # print()

    display(df_counts_yes)
# Out:
#                    non_hispanic_race diabetes  house_family_person_id  Total  \
# 9   Indian (American), Alaska Native      YES                      73    428
# 3             Black/African American      YES                     547   3723
# 7                           Filipino      YES                      44    401
# 17                             White      YES                    2705  26420
# 13                       Other Asian      YES                      50    601
# 1                       Asian Indian      YES                      21    335
# 5                            Chinese      YES                      14    325
#
#     Percentage
# 9     0.170561
# 3     0.146925
# 7     0.109726
# 17    0.102385
# 13    0.083195
# 1     0.062687
# 5     0.043077
#                    non_hispanic_race smoker  house_family_person_id  Total  \
# 9   Indian (American), Alaska Native    YES                     212    428
# 17                             White    YES                   11301  26420
# 3             Black/African American    YES                    1308   3723
# 7                           Filipino    YES                     129    401
# 13                       Other Asian    YES                     175    601
# 5                            Chinese    YES                      51    325
# 1                       Asian Indian    YES                      48    335
#
#     Percentage
# 9     0.495327
# 17    0.427744
# 3     0.351330
# 7     0.321696
# 13    0.291181
# 5     0.156923
# 1     0.143284
#                    non_hispanic_race coronary_heart_disease  \
# 17                             White                    YES
# 9   Indian (American), Alaska Native                    YES
# 3             Black/African American                    YES
# 13                       Other Asian                    YES
# 7                           Filipino                    YES
# 1                       Asian Indian                    YES
# 5                            Chinese                    YES
#
#     house_family_person_id  Total  Percentage
# 17                    1535  26420    0.058100
# 9                       24    428    0.056075
# 3                      185   3723    0.049691
# 13                      20    601    0.033278
# 7                       12    401    0.029925
# 1                        7    335    0.020896
# 5                        5    325    0.015385
#                    non_hispanic_race had_high_cholesterol  \
# 7                           Filipino                  YES
# 17                             White                  YES
# 13                       Other Asian                  YES
# 3             Black/African American                  YES
# 9   Indian (American), Alaska Native                  YES
# 5                            Chinese                  YES
# 1                       Asian Indian                  YES
#
#     house_family_person_id  Total  Percentage
# 7                       96    401    0.239401
# 17                    6015  26420    0.227668
# 13                     133    601    0.221298
# 3                      823   3723    0.221058
# 9                       80    428    0.186916
# 5                       48    325    0.147692
# 1                       40    335    0.119403
#                    non_hispanic_race hypertension  house_family_person_id  \
# 3             Black/African American          YES                    1677
# 7                           Filipino          YES                     156
# 17                             White          YES                    9219
# 9   Indian (American), Alaska Native          YES                     139
# 13                       Other Asian          YES                     173
# 5                            Chinese          YES                      74
# 1                       Asian Indian          YES                      56
#
#     Total  Percentage
# 3    3723    0.450443
# 7     401    0.389027
# 17  26420    0.348940
# 9     428    0.324766
# 13    601    0.287854
# 5     325    0.227692
# 1     335    0.167164
#                    non_hispanic_race heart_condition  house_family_person_id  \
# 17                             White             YES                    2555
# 9   Indian (American), Alaska Native             YES                      34
# 3             Black/African American             YES                     247
# 5                            Chinese             YES                      15
# 13                       Other Asian             YES                      26
# 7                           Filipino             YES                      15
# 1                       Asian Indian             YES                       5
#
#     Total  Percentage
# 17  26420    0.096707
# 9     428    0.079439
# 3    3723    0.066344
# 5     325    0.046154
# 13    601    0.043261
# 7     401    0.037406
# 1     335    0.014925
#                    non_hispanic_race cancer  house_family_person_id  Total  \
# 17                             White    YES                    3329  26420
# 13                       Other Asian    YES                      44    601
# 7                           Filipino    YES                      27    401
# 9   Indian (American), Alaska Native    YES                      28    428
# 3             Black/African American    YES                     211   3723
# 5                            Chinese    YES                       8    325
# 1                       Asian Indian    YES                       2    335
#
#     Percentage
# 17    0.126003
# 13    0.073211
# 7     0.067332
# 9     0.065421
# 3     0.056675
# 5     0.024615
# 1     0.005970
#                    non_hispanic_race kidney_condition  house_family_person_id  \
# 2             Black/African American              YES                     119
# 8   Indian (American), Alaska Native              YES                      12
# 16                             White              YES                     640
# 12                       Other Asian              YES                       9
# 4                            Chinese              YES                       4
# 6                           Filipino              YES                       3
#
#     Total  Percentage
# 2    3723    0.031963
# 8     428    0.028037
# 16  26420    0.024224
# 12    601    0.014975
# 4     325    0.012308
# 6     401    0.007481
#                    non_hispanic_race liver_condition  house_family_person_id  \
# 13                       Other Asian             YES                      21
# 9   Indian (American), Alaska Native             YES                      13
# 17                             White             YES                     563
# 3             Black/African American             YES                      60
# 5                            Chinese             YES                       5
# 7                           Filipino             YES                       6
# 1                       Asian Indian             YES                       2
#
#     Total  Percentage
# 13    601    0.034942
# 9     428    0.030374
# 17  26420    0.021310
# 3    3723    0.016116
# 5     325    0.015385
# 7     401    0.014963
# 1     335    0.005970
#                    non_hispanic_race cant_afford_meds  house_family_person_id  \
# 5             Black/African American              YES                     365
# 14  Indian (American), Alaska Native              YES                      37
# 25                             White              YES                    1648
# 11                          Filipino              YES                      18
# 20                       Other Asian              YES                      21
# 8                            Chinese              YES                       7
# 2                       Asian Indian              YES                       4
#
#     Total  Percentage
# 5    3723    0.098039
# 14    428    0.086449
# 25  26420    0.062377
# 11    401    0.044888
# 20    601    0.034942
# 8     325    0.021538
# 2     335    0.011940
#                    non_hispanic_race skipped_meds  house_family_person_id  \
# 6             Black/African American          YES                     189
# 15  Indian (American), Alaska Native          YES                      21
# 28                             White          YES                    1063
# 21                       Other Asian          YES                      18
# 12                          Filipino          YES                      12
# 9                            Chinese          YES                       4
# 2                       Asian Indian          YES                       4
#
#     Total  Percentage
# 6    3723    0.050766
# 15    428    0.049065
# 28  26420    0.040235
# 21    601    0.029950
# 12    401    0.029925
# 9     325    0.012308
# 2     335    0.011940

# %%
df_diseases = pd.DataFrame(dict_diseases_race, index=['Most Affected', 'Second Most', 'Third Most']).T.sort_values(['Most Affected', 'Second Most', 'Third Most'])
df_diseases
# Out:
#                                            Most Affected  \
# hypertension                      Black/African American
# kidney_condition                  Black/African American
# cant_afford_meds                  Black/African American
# skipped_meds                      Black/African American
# had_high_cholesterol                            Filipino
# diabetes                Indian (American), Alaska Native
# smoker                  Indian (American), Alaska Native
# liver_condition                              Other Asian
# coronary_heart_disease                             White
# heart_condition                                    White
# cancer                                             White
#
#                                              Second Most  \
# hypertension                                    Filipino
# kidney_condition        Indian (American), Alaska Native
# cant_afford_meds        Indian (American), Alaska Native
# skipped_meds            Indian (American), Alaska Native
# had_high_cholesterol                               White
# diabetes                          Black/African American
# smoker                                             White
# liver_condition         Indian (American), Alaska Native
# coronary_heart_disease  Indian (American), Alaska Native
# heart_condition         Indian (American), Alaska Native
# cancer                                       Other Asian
#
#                                     Third Most
# hypertension                             White
# kidney_condition                         White
# cant_afford_meds                         White
# skipped_meds                             White
# had_high_cholesterol               Other Asian
# diabetes                              Filipino
# smoker                  Black/African American
# liver_condition                          White
# coronary_heart_disease  Black/African American
# heart_condition         Black/African American
# cancer                                Filipino

# %%
df_diseases.reset_index().groupby(['Most Affected']).agg({'index':"unique"})
# Out:
#                                                                               index
# Most Affected
# Black/African American            [hypertension, kidney_condition, cant_afford_m...
# Filipino                                                     [had_high_cholesterol]
# Indian (American), Alaska Native                                 [diabetes, smoker]
# Other Asian                                                       [liver_condition]
# White                             [coronary_heart_disease, heart_condition, cancer]
